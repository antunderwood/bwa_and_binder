# %%
# index reference and change prefix to typhi
# !bwa index data/reference.fasta -p data/typhi

# %%
# map reads filter for only those reads that are mapped and sort
# !bwa mem data/typhi data/ERR668456_1.fastq.gz data/ERR668456_2.fastq.gz  | \
samtools view -F 4 -b | \
samtools sort -o results/output.bam

# %%
# report mapping stats
# !samtools flagstat results/output.bam
